# %%
import pandas as pd

exported_data = 'user_progress_export_20251004_181606.csv'

df = pd.read_csv(exported_data)

df.head()
# Out:
#   username                   timestamp scenario_id  total_score  \
# 0      Vic  2025-09-30T13:26:40.081775          b3           67
# 1   airees  2025-09-30T10:41:27.536280          b1           89
# 2   airees  2025-09-30T11:42:39.939033          b3           70
# 3   airees  2025-09-30T13:21:34.075987          b3           83
# 4   airees  2025-09-30T13:55:19.421665          b3           80
#
#    clarity_score  specificity_score  structure_score  task_alignment_score  \
# 0             22                 10               23                    12
# 1             22                 20               23                    24
# 2             18                 15               17                    20
# 3             23                 15               20                    25
# 4             23                 12               20                    25
#
#   skill_level  total_attempts  cumulative_score  avg_score  badges_count  \
# ...
